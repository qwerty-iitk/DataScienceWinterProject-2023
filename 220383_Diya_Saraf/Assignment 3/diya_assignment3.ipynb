# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score

# %%
df= pd.read_csv("winequality-red.csv")

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df['quality_check'] = np.where(df['quality'] >= 6, 1, 0)

# %%
df.drop('quality', axis=1, inplace=True)

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality_check
# 0      9.4              0
# 1      9.8              0
# ...

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality_check           0
# dtype: int64

# %%
correlation_matrix = df.corr()

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
corr= df.corr()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(corr, annot=True, cmap= 'coolwarm')
# Out:
# <Axes: >

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1
df_no_outliers = df[~((df < (Q1 - 1.5 * IQR)) | (df > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
print(f"Number of rows before handling outliers: {df.shape[0]}")
print(f"Number of rows after handling outliers: {df_no_outliers.shape[0]}")
# Out:
# Number of rows before handling outliers: 1599
# Number of rows after handling outliers: 1194

# %%
df_no_outliers.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality_check
# 0      9.4              0
# 1      9.8              0
# ...

# %%
scaler = StandardScaler()
df_normalized = pd.DataFrame(scaler.fit_transform(df_no_outliers.drop('quality_check', axis=1)),
                             columns=df_no_outliers.drop('quality_check', axis=1).columns)

# %%
df['quality_check'].value_counts()
# Out:
# 1    855
# 0    744
# Name: quality_check, dtype: int64

# %%
df['quality_check'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
x = df_normalized
y = df_no_outliers['quality_check']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
df_normalized.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0      -0.524869          1.075573    -1.377452       -0.646558  -0.173311
# 1      -0.250994          2.167738    -1.377452        0.937243   1.365747
# 2      -0.250994          1.439628    -1.155393        0.258471   0.946004
# 3       2.076938         -1.472812     1.731370       -0.646558  -0.243268
# 4      -0.524869          1.075573    -1.377452       -0.646558  -0.173311
#
#    free sulfur dioxide  total sulfur dioxide   density        pH  sulphates  \
# 0            -0.454417             -0.312763  0.766056  1.408196  -0.621576
# 1             1.133715              0.952872  0.142508 -0.938945   0.411596
# 2            -0.000665              0.454289  0.267217 -0.484660   0.153303
# 3             0.226211              0.684404  0.890766 -1.241802  -0.449381
# 4            -0.454417             -0.312763  0.766056  1.408196  -0.621576
#
#     alcohol
# 0 -0.989805
# 1 -0.579638
# 2 -0.579638
# ...

# %%
#Decision Trees Classifier

# %%
dt_classifier = DecisionTreeClassifier(random_state=42)
dt_classifier.fit(x_train, y_train)
dt_predictions = dt_classifier.predict(x_test)

# %%
#Random Forest Classifier

# %%
rf_classifier = RandomForestClassifier(random_state=42)
rf_classifier.fit(x_train, y_train)
rf_predictions = rf_classifier.predict(x_test)

# %%
dt_accuracy = accuracy_score(y_test, dt_predictions)
dt_f1_score = f1_score(y_test, dt_predictions)

# %%
rf_accuracy = accuracy_score(y_test, rf_predictions)
rf_f1_score = f1_score(y_test, rf_predictions)

# %%
print("Decision Trees Classifier:")
print(f"Accuracy: {dt_accuracy:.4f}")
print(f"F1 Score: {dt_f1_score:.4f}\n")

print("Random Forest Classifier:")
print(f"Accuracy: {rf_accuracy:.4f}")
print(f"F1 Score: {rf_f1_score:.4f}")
# Out:
# Decision Trees Classifier:
# Accuracy: 0.7322
# F1 Score: 0.7557
#
# Random Forest Classifier:
# Accuracy: 0.7908
# F1 Score: 0.8016
