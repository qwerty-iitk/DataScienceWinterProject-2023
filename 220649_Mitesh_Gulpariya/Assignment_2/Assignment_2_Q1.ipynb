# %% [markdown]
# # Assignment 2

# %%
# Importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from math import exp
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression

# %%
# loading dataset
data = pd.read_csv("C:\\Users\\mites\\Downloads\\Social_Network_Ads.csv")
data
# Out:
#       User ID  Gender  Age  EstimatedSalary  Purchased
# 0    15624510    Male   19            19000          0
# 1    15810944    Male   35            20000          0
# 2    15668575  Female   26            43000          0
# 3    15603246  Female   27            57000          0
# 4    15804002    Male   19            76000          0
# ..        ...     ...  ...              ...        ...
# 395  15691863  Female   46            41000          1
# 396  15706071    Male   51            23000          1
# 397  15654296  Female   50            20000          1
# 398  15755018    Male   36            33000          0
# 399  15594041  Female   49            36000          1
#
# [400 rows x 5 columns]

# %%
data.shape
# Out:
# (400, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   User ID          400 non-null    int64
#  1   Gender           400 non-null    object
#  2   Age              400 non-null    int64
#  3   EstimatedSalary  400 non-null    int64
#  4   Purchased        400 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 15.8+ KB

# %%
data.describe()
# Out:
#             User ID         Age  EstimatedSalary   Purchased
# count  4.000000e+02  400.000000       400.000000  400.000000
# mean   1.569154e+07   37.655000     69742.500000    0.357500
# std    7.165832e+04   10.482877     34096.960282    0.479864
# min    1.556669e+07   18.000000     15000.000000    0.000000
# 25%    1.562676e+07   29.750000     43000.000000    0.000000
# 50%    1.569434e+07   37.000000     70000.000000    0.000000
# 75%    1.575036e+07   46.000000     88000.000000    1.000000
# max    1.581524e+07   60.000000    150000.000000    1.000000

# %%
# Extract feature and target matrices
features = data[['Age', 'EstimatedSalary']]
targets = data['Purchased']

# Split the data into training and test sets with a 70:30 ratio
X_train, X_test, y_train, y_test = train_test_split(features, targets, test_size=0.3, random_state=42)

# %%
# sigmoid function
def sigmoid(x):
    return (1/(1+np.exp(-x)))

# %%
# Logistic regression from scratch
class LogisticRegression():

    def __init__(self, L=0.001, n_iters=1000):
        self.L = L
        self.n_iters = n_iters
        self.weights = None
        self.bias = None

    def fit(self, X, y):
        n_samples, n_features = X.shape
        self.weights = np.zeros(n_features)
        self.bias = 0

        for _ in range(self.n_iters):
            linear_pred = np.dot(X, self.weights) + self.bias
            linear_pred = np.array(linear_pred, dtype = np.longfloat)
            predictions = sigmoid(linear_pred)

            dw = (1/n_samples) * np.dot(X.T, (predictions - y))
            db = (1/n_samples) * np.sum(predictions-y)

            self.weights = self.weights - self.L*dw
            self.bias = self.bias - self.L*db


    def predict(self, X):
        linear_pred = np.dot(X, self.weights) + self.bias
        y_pred = sigmoid(linear_pred)
        class_pred = [0 if y<=0.5 else 1 for y in y_pred]
        return class_pred

# %%
clf = LogisticRegression(L=0.01)
clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)

def accuracy(y_pred, y_test):
    return np.sum(y_pred==y_test)/len(y_test)

acc = accuracy(y_pred, y_test)
print(acc)
# Out:
# C:\Users\mites\AppData\Local\Temp\ipykernel_12944\635698299.py:3: RuntimeWarning: overflow encountered in exp
#   return (1/(1+np.exp(-x)))
# C:\Users\mites\AppData\Local\Temp\ipykernel_12944\635698299.py:3: RuntimeWarning: overflow encountered in exp
#   return (1/(1+np.exp(-x)))
# C:\Users\mites\AppData\Local\Temp\ipykernel_12944\635698299.py:3: RuntimeWarning: overflow encountered in exp
#   return (1/(1+np.exp(-x)))
# C:\Users\mites\AppData\Local\Temp\ipykernel_12944\635698299.py:3: RuntimeWarning: overflow encountered in exp
#   return (1/(1+np.exp(-x)))
# C:\Users\mites\AppData\Local\Temp\ipykernel_12944\635698299.py:3: RuntimeWarning: overflow encountered in exp
#   return (1/(1+np.exp(-x)))
# C:\Users\mites\AppData\Local\Temp\ipykernel_12944\635698299.py:3: RuntimeWarning: overflow encountered in exp
#   return (1/(1+np.exp(-x)))
# C:\Users\mites\AppData\Local\Temp\ipykernel_12944\635698299.py:3: RuntimeWarning: overflow encountered in exp
#   return (1/(1+np.exp(-x)))
# ...

# %%
scaler = StandardScaler()

X_train1 = scaler.fit_transform(X_train)

X_test1  = scaler.transform(X_test)

# %%
clf.fit(X_train1,y_train)
y_pred = clf.predict(X_test1)
acc = accuracy(y_pred, y_test)
print(acc)
# Out:
# 0.8416666666666667

# %%
scaler1 = MinMaxScaler()

X_train2 = scaler1.fit_transform(X_train)

X_test2  = scaler1.transform(X_test)

# %%
clf.fit(X_train2,y_train)
y_pred = clf.predict(X_test2)
acc = accuracy(y_pred, y_test)
print(acc)
# Out:
# 0.6083333333333333

# %%
# On unscaled dataset Using sklearn
lr_model = LogisticRegression()
lr_model.fit(X_train, y_train)


y_pred_sk = lr_model.predict(X_test)
acc = accuracy(y_pred_sk,y_test)
print(acc)
# Out:
# C:\Users\mites\AppData\Local\Temp\ipykernel_12944\635698299.py:3: RuntimeWarning: overflow encountered in exp
#   return (1/(1+np.exp(-x)))
# C:\Users\mites\AppData\Local\Temp\ipykernel_12944\635698299.py:3: RuntimeWarning: overflow encountered in exp
#   return (1/(1+np.exp(-x)))
# C:\Users\mites\AppData\Local\Temp\ipykernel_12944\635698299.py:3: RuntimeWarning: overflow encountered in exp
#   return (1/(1+np.exp(-x)))
# C:\Users\mites\AppData\Local\Temp\ipykernel_12944\635698299.py:3: RuntimeWarning: overflow encountered in exp
#   return (1/(1+np.exp(-x)))
# C:\Users\mites\AppData\Local\Temp\ipykernel_12944\635698299.py:3: RuntimeWarning: overflow encountered in exp
#   return (1/(1+np.exp(-x)))
# C:\Users\mites\AppData\Local\Temp\ipykernel_12944\635698299.py:3: RuntimeWarning: overflow encountered in exp
#   return (1/(1+np.exp(-x)))
# C:\Users\mites\AppData\Local\Temp\ipykernel_12944\635698299.py:3: RuntimeWarning: overflow encountered in exp
#   return (1/(1+np.exp(-x)))
# ...

# %%
# On standardised dataset
lr_model.fit(X_train1, y_train)
y_pred_sk1 = lr_model.predict(X_test1)
acc = accuracy(y_pred_sk1,y_test)
print(acc)
# Out:
# 0.8416666666666667

# %%
# On normalised dataset
lr_model.fit(X_train2, y_train)
y_pred_sk2 = lr_model.predict(X_test2)
acc = accuracy(y_pred_sk2,y_test)
print(acc)
# Out:
# 0.6083333333333333
